# %%
# ! pip install matplotlib
# ! pip install pandas
# ! pip install numpy

# %%
import matplotlib.pyplot as plt # The plotting library
import numpy as np 
import pandas as pd # Library for working with tabular data, such as CSV and TSV

# Magic command for showing plot inline
# %matplotlib inline

# %% [markdown]
# # Some basics

# %%
# Create a figure 
# fig, ax OR plt.plot()

plt.plot() # Create an empty figure
# Out:
# []

# %%
# Create a figure 
# fig, ax OR plt.plot()
fig, ax = plt.subplots() # Create an empty figure

# %%
# Create a figure having two horizonal subplots.
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# 1 in subplots(1, 2) indicates the number of rows in the figure
# 2 in subplots(1, 2) indicates the number of colum in the figure
# figsize=(10, 5) indicates this is an 10 inch by 5 inch figure

# %%
# Create a figure having two vertical subplots.
fig, ax = plt.subplots(2, 1, figsize=(5, 10))

# 2 in subplots(2, 1) indicates the number of rows in the figure
# 1 in subplots(2, 1) indicates the number of colum in the figure
# figsize=(5, 10) indicates this is an 5 inch by 10 inch figure

# %%
# Create a figure having four subplots.
fig, ax = plt.subplots(2, 2)

# subplots(2, 2) tells matplotlib to draw a figure with 2 by 2 subplots in it.

# %%
# plot a line

x = [1, 2, 3, 4] # x coordinates
y = [4, 3, 4, 3] # y coordinates

fig, ax = plt.subplots() # Make an empty figure
ax.plot(x, y) # draw a line on the figure. The line is drawn from the x and y coordinates.

plt.show()

# %%
# plot two lines in one figure
x = [1, 2, 3, 4]
y = [4, 3, 4, 3]

y1 = [3, 3, 3, 3]

fig, ax = plt.subplots()
ax.plot(x, y) # Plot the first line using the x and y coordinates.
ax.plot(x, y1, linewidth=10) # Plot the second line using the x and y1 coordinates.

plt.show()

# %%
# plot two lines in two subplots (1*2)

fig, ax = plt.subplots(1, 2)

ax[0].plot(x, y) 
# Plot the first line using the x and y coordinates.
# here, the 0 in ax[0] picks the first axis, which is the left subplot

ax[1].plot(x, y1) 
# Plot the second line using the x and y1 coordinates.
# here, the 1 in ax[1] picks the second axis, which is the right subplot

plt.show()

# %%
# plot lines in subplots (2*2)

fig, ax = plt.subplots(2, 2)

# color= indicate the color of the line
# 'r' is red, 'b' is blue, and 'k' is black

ax[0, 0].plot(x, y, color='r') # upper left
# ax[0, 0] picks the axis at the first row (0) and the first column (0) in the figure, which is the upper left subplot.

ax[0, 1].plot(x, y1, color='b') # upper right
# ax[0, 1] picks the axis at the first row (0) and the second column (1)

ax[1, 0].plot(x, y, color='k') # lower left
# ax[1, 0] picks the axis at the second row (1) and the first column (0)

ax[1, 1].plot(x, y1, color='orange') # lower right
# ax[1, 1] picks the axis at the second row (1) and the second column (1)

plt.show()

# %% [markdown]
# # Pandas

# %%
# !wget https://uiuc-ischool-dataviz.github.io/spring2019online/week02/building_inventory.csv
    
# This is for downloading the CSV file
# Out:
# --2022-09-01 23:20:07--  https://uiuc-ischool-dataviz.github.io/spring2019online/week02/building_inventory.csv
# Resolving uiuc-ischool-dataviz.github.io (uiuc-ischool-dataviz.github.io)... 185.199.111.153, 185.199.108.153, 185.199.110.153, ...
# Connecting to uiuc-ischool-dataviz.github.io (uiuc-ischool-dataviz.github.io)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1994275 (1.9M) [text/csv]
# Saving to: ‘building_inventory.csv.4’
#
# building_inventory. 100%[===================>]   1.90M  --.-KB/s    in 0.04s
#
# 2022-09-01 23:20:07 (50.7 MB/s) - ‘building_inventory.csv.4’ saved [1994275/1994275]

# %%
# Read file

df = pd.read_csv('building_inventory.csv', sep=',') 
# sep is the separator. 
# sep=',' for CSV and sep='\t' for TSV 

df.head() # Show the fisrt 5 row in the CSV file
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
# 3  Department of Natural Resources
# 4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
# 3  Astoria     61501  Fulton             17            Cheri Bustos        93
# 4  Astoria     61501  Fulton             17            Cheri Bustos        93
#
#        Rep Full Name  ...  Bldg Status Year Acquired Year Constructed  \
# 0  Hammond Norine K.  ...       In Use          1975             1975
# 1  Hammond Norine K.  ...       In Use          2004             2004
# 2  Hammond Norine K.  ...       In Use          2004             2004
# 3  Hammond Norine K.  ...       In Use          2004             2004
# 4  Hammond Norine K.  ...       In Use          2004             2004
#
#    Square Footage  Total Floors  Floors Above Grade  Floors Below Grade  \
# 0             144             1                   1                   0
# 1             144             1                   1                   0
# 2             144             1                   1                   0
# 3             144             1                   1                   0
# 4             144             1                   1                   0
#
#    Usage Description  Usage Description 2 Usage Description 3
# 0            Unusual              Unusual        Not provided
# 1            Unusual              Unusual        Not provided
# 2            Unusual              Unusual        Not provided
# 3            Unusual              Unusual        Not provided
# 4            Unusual              Unusual        Not provided
#
# [5 rows x 22 columns]

# %%
# Number of rows and columns

df.shape # returns the number of rows and columns (n_rows, n_cols)
# Out:
# (8862, 22)

# %%
# Assign ID to each building

df = df.reset_index() # reset the index as a colum
df = df.rename(columns={'index':'Building ID'}) # rename the "index" colum we just reset as the name 'Building ID'
df.head()
# Out:
#    Building ID                      Agency Name  \
# 0            0  Department of Natural Resources
# 1            1  Department of Natural Resources
# 2            2  Department of Natural Resources
# 3            3  Department of Natural Resources
# 4            4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
# 3  Astoria     61501  Fulton             17            Cheri Bustos        93
# 4  Astoria     61501  Fulton             17            Cheri Bustos        93
#
#    ... Bldg Status  Year Acquired Year Constructed Square Footage  \
# 0  ...      In Use           1975             1975            144
# 1  ...      In Use           2004             2004            144
# 2  ...      In Use           2004             2004            144
# 3  ...      In Use           2004             2004            144
# 4  ...      In Use           2004             2004            144
#
#    Total Floors  Floors Above Grade  Floors Below Grade  Usage Description  \
# 0             1                   1                   0            Unusual
# 1             1                   1                   0            Unusual
# 2             1                   1                   0            Unusual
# 3             1                   1                   0            Unusual
# 4             1                   1                   0            Unusual
#
#    Usage Description 2  Usage Description 3
# 0              Unusual         Not provided
# 1              Unusual         Not provided
# 2              Unusual         Not provided
# 3              Unusual         Not provided
# 4              Unusual         Not provided
#
# [5 rows x 23 columns]

# %%
# Summary of a DataFrame.

df.info() 

# Dtype shows the data type of each column 
# Non-Null Count shows the number of row that is not null (i.e., have values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8862 entries, 0 to 8861
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Building ID              8862 non-null   int64
#  1   Agency Name              8862 non-null   object
#  2   Location Name            8862 non-null   object
#  3   Address                  8811 non-null   object
#  4   City                     8862 non-null   object
#  5   Zip code                 8862 non-null   int64
#  6   County                   8837 non-null   object
#  7   Congress Dist            8862 non-null   int64
#  8   Congressional Full Name  8699 non-null   object
#  9   Rep Dist                 8862 non-null   int64
#  10  Rep Full Name            8839 non-null   object
#  11  Senate Dist              8862 non-null   int64
#  12  Senator Full Name        8839 non-null   object
#  13  Bldg Status              8862 non-null   object
#  14  Year Acquired            8862 non-null   int64
#  15  Year Constructed         8862 non-null   int64
#  16  Square Footage           8862 non-null   int64
#  17  Total Floors             8862 non-null   int64
#  18  Floors Above Grade       8862 non-null   int64
#  19  Floors Below Grade       8862 non-null   int64
#  20  Usage Description        8862 non-null   object
#  21  Usage Description 2      8832 non-null   object
#  22  Usage Description 3      8774 non-null   object
# dtypes: int64(11), object(12)
# memory usage: 1.6+ MB

# %%
# Descriptive statistics of the numerical columns

df.describe()
# Out:
#        Building ID      Zip code  Congress Dist     Rep Dist  Senate Dist  \
# count  8862.000000   8862.000000    8862.000000  8862.000000  8862.000000
# mean   4430.500000  61821.076845      13.404085    92.303318    46.408599
# std    2558.383376   1095.203357       4.037936    23.568457    11.781038
# min       0.000000   1235.000000       0.000000     0.000000     0.000000
# 25%    2215.250000  61105.000000      12.000000    79.000000    40.000000
# 50%    4430.500000  62023.000000      14.000000    97.000000    49.000000
# 75%    6645.750000  62650.000000      16.000000   110.000000    55.000000
# max    8861.000000  68297.000000      18.000000   119.000000    60.000000
#
#        Year Acquired  Year Constructed  Square Footage  Total Floors  \
# count    8862.000000       8862.000000    8.862000e+03   8862.000000
# mean     1913.267660       1906.135184    1.147603e+04      1.636087
# std       337.024796        351.180642    3.817263e+04      1.537603
# min         0.000000          0.000000    0.000000e+00      0.000000
# 25%      1957.000000       1953.000000    2.330000e+02      1.000000
# 50%      1975.000000       1974.000000    1.600000e+03      1.000000
# 75%      1992.000000       1991.000000    6.426500e+03      2.000000
# max      2019.000000       2019.000000    1.200000e+06     31.000000
#
#        Floors Above Grade  Floors Below Grade
# count         8862.000000         8862.000000
# mean             1.449334            0.161589
# std              1.286898            0.392717
# min              0.000000            0.000000
# 25%              1.000000            0.000000
# 50%              1.000000            0.000000
# 75%              1.000000            0.000000
# max             30.000000            4.000000

# %%
# Covert data type

df['Zip code'] = df['Zip code'].astype(str) 
# Change the data type of 'Zip code' column from integer to string
# [] in df['Zip code'] is for selecting the 'Zip code' column

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8862 entries, 0 to 8861
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Building ID              8862 non-null   int64
#  1   Agency Name              8862 non-null   object
#  2   Location Name            8862 non-null   object
#  3   Address                  8811 non-null   object
#  4   City                     8862 non-null   object
#  5   Zip code                 8862 non-null   object
#  6   County                   8837 non-null   object
#  7   Congress Dist            8862 non-null   int64
#  8   Congressional Full Name  8699 non-null   object
#  9   Rep Dist                 8862 non-null   int64
#  10  Rep Full Name            8839 non-null   object
#  11  Senate Dist              8862 non-null   int64
#  12  Senator Full Name        8839 non-null   object
#  13  Bldg Status              8862 non-null   object
#  14  Year Acquired            8862 non-null   int64
#  15  Year Constructed         8862 non-null   int64
#  16  Square Footage           8862 non-null   int64
#  17  Total Floors             8862 non-null   int64
#  18  Floors Above Grade       8862 non-null   int64
#  19  Floors Below Grade       8862 non-null   int64
#  20  Usage Description        8862 non-null   object
#  21  Usage Description 2      8832 non-null   object
#  22  Usage Description 3      8774 non-null   object
# dtypes: int64(10), object(13)
# memory usage: 1.6+ MB

# %%
# Missing values
df.isna().sum() 
# isna() select the rows having null values (i.e., missing values), and sum() counts the number of rows having null values.
# Out:
# Building ID                  0
# Agency Name                  0
# Location Name                0
# Address                     51
# City                         0
# Zip code                     0
# County                      25
# Congress Dist                0
# Congressional Full Name    163
# Rep Dist                     0
# Rep Full Name               23
# Senate Dist                  0
# Senator Full Name           23
# Bldg Status                  0
# Year Acquired                0
# Year Constructed             0
# Square Footage               0
# Total Floors                 0
# Floors Above Grade           0
# Floors Below Grade           0
# Usage Description            0
# Usage Description 2         30
# Usage Description 3         88
# dtype: int64

# %%
# Unique values in a column
df['Year Acquired'].unique()
# Out:
# array([1975, 2004, 2000, 1999, 1980, 1997, 1976, 1994, 2001, 1993, 1972,
#        1970, 1996, 2002, 2006, 1988, 1998, 1981, 1995, 1987, 1985, 1930,
#        1986, 1956, 1973, 1964, 2003, 1982, 1966, 1946, 1960, 1942, 1990,
#        1978, 1984, 1947, 1926, 1910, 1949, 1963, 1968,    0, 1929, 1917,
#        1967, 1989, 1979, 1920, 2005, 1885, 1940, 1950, 1983, 1958, 1961,
#        1971, 1991, 1992, 1954, 1932, 1900, 1867, 1965, 1953, 1907, 1935,
#        1951, 1977, 2010, 2007, 2011, 1974, 1955, 1857, 2008, 1959, 1952,
#        1957, 1948, 1927, 1923, 1962, 1913, 1945, 1936, 1944, 1939, 1933,
#        1921, 1925, 1875, 1876, 1969, 1931, 1903, 1880, 1848, 1918, 1922,
#        2014, 1905, 1915, 1886, 1832, 1908, 1919, 1941, 1840, 1810, 1937,
#        1855, 1860, 1850, 1856, 1883, 1753, 1924, 1802, 1859, 1844, 1838,
#        1891, 1854, 1843, 1898, 1901, 1874, 1845, 1841, 1904, 1839, 1837,
#        1938, 1890, 1934, 1928, 1916, 1943, 1899, 1912, 1887, 1892, 1882,
#        1881, 1911, 1858, 1865, 1895, 1893, 1888, 1902, 1863, 1909, 1906,
#        2009, 1894, 1896, 1853, 1872, 1871, 1914, 1878, 1870, 1873, 1897,
#        2013, 2012, 2016, 2015, 2018, 2017, 2019])

# %%
# Arithmetic operation

df['Age at Acqusition'] = df['Year Acquired'] - df['Year Constructed']
# This adds a new column 'Age at Acqusition' to the dataframe

df.head()
# Out:
#    Building ID                      Agency Name  \
# 0            0  Department of Natural Resources
# 1            1  Department of Natural Resources
# 2            2  Department of Natural Resources
# 3            3  Department of Natural Resources
# 4            4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria    61501  Fulton             17            Cheri Bustos        93
# 1  Astoria    61501  Fulton             17            Cheri Bustos        93
# 2  Astoria    61501  Fulton             17            Cheri Bustos        93
# 3  Astoria    61501  Fulton             17            Cheri Bustos        93
# 4  Astoria    61501  Fulton             17            Cheri Bustos        93
#
#    ... Year Acquired  Year Constructed Square Footage Total Floors  \
# 0  ...          1975              1975            144            1
# 1  ...          2004              2004            144            1
# 2  ...          2004              2004            144            1
# 3  ...          2004              2004            144            1
# 4  ...          2004              2004            144            1
#
#    Floors Above Grade  Floors Below Grade  Usage Description  \
# 0                   1                   0            Unusual
# 1                   1                   0            Unusual
# 2                   1                   0            Unusual
# 3                   1                   0            Unusual
# 4                   1                   0            Unusual
#
#    Usage Description 2  Usage Description 3  Age at Acqusition
# 0              Unusual         Not provided                  0
# 1              Unusual         Not provided                  0
# 2              Unusual         Not provided                  0
# 3              Unusual         Not provided                  0
# 4              Unusual         Not provided                  0
#
# [5 rows x 24 columns]

# %%
# Filter by relationship

fiter_1 = df['Year Acquired'] > 0 
# for selecting rows that the value in 'Year Acquired' greater than 0

fiter_2 = df['Year Constructed'] > 0
# for selecting rows that the value in 'Year Constructed' greater than 0

fiter_3 = df['Age at Acqusition'] >= 0
# for selecting rows that the value in 'Age at Acqusition' greater than or equal to 0


df_filtered = df.loc[(fiter_1)&(fiter_2)&(fiter_3)].copy()
# .loc[] select rows based on the filter (or filters) applied to the column (or columns)

# .loc[(fiter_1)&(fiter_2)&(fiter_3)] means that I select rows that satisfy all three filters.
# in other words, the selected rows meet all the three conditions:
# 1 - 'Year Acquired' is greater than 0
# 2 - 'Year Constructed' is greater than 0, and 
# 3 - 'Age at Acqusition' is greater than or equal to 0.

# .copy() is to copy the selected rows as a new dataframe

print(df.shape) # print n_rows, n_cols in the original dataframe
print(df_filtered.shape) # print n_rows, n_cols in the new dataframe (the selected one)
# Out:
# (8862, 24)
# (8393, 24)

# %%
# Filter by relationship, set based

rows_in_2004_2006 = df.loc[df['Year Acquired'].isin([2004, 2006])]
# Filter performed on one colum, 'Year Acquired', that the year value in 'Year Acquired' is in [2004, 2006]

print(rows_in_2004_2006.shape) # n_cols, n_rows after filtering
print(rows_in_2004_2006['Year Acquired'].unique()) # unique values in the Year Acquired colum after filtering
rows_in_2004_2006.head()
# Out:
# (272, 24)
# [2004 2006]
#    Building ID                      Agency Name  \
# 1            1  Department of Natural Resources
# 2            2  Department of Natural Resources
# 3            3  Department of Natural Resources
# 4            4  Department of Natural Resources
# 5            5  Department of Natural Resources
#
#                                      Location Name             Address  \
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 5  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 1  Astoria    61501  Fulton             17            Cheri Bustos        93
# 2  Astoria    61501  Fulton             17            Cheri Bustos        93
# 3  Astoria    61501  Fulton             17            Cheri Bustos        93
# 4  Astoria    61501  Fulton             17            Cheri Bustos        93
# 5  Astoria    61501  Fulton             17            Cheri Bustos        93
#
#    ... Year Acquired  Year Constructed Square Footage Total Floors  \
# 1  ...          2004              2004            144            1
# 2  ...          2004              2004            144            1
# 3  ...          2004              2004            144            1
# 4  ...          2004              2004            144            1
# 5  ...          2004              2004            144            1
#
#    Floors Above Grade  Floors Below Grade  Usage Description  \
# 1                   1                   0            Unusual
# 2                   1                   0            Unusual
# 3                   1                   0            Unusual
# 4                   1                   0            Unusual
# 5                   1                   0            Unusual
#
#    Usage Description 2  Usage Description 3  Age at Acqusition
# 1              Unusual         Not provided                  0
# 2              Unusual         Not provided                  0
# 3              Unusual         Not provided                  0
# 4              Unusual         Not provided                  0
# 5              Unusual         Not provided                  0
#
# [5 rows x 24 columns]

# %%
# Sampling, by number
df.sample(30) # Get a sample that has 30 records.
# Out:
#       Building ID                       Agency Name  \
# 4269         4269      Department of Human Services
# 5535         5535         Department of Corrections
# 1557         1557   Department of Natural Resources
# 3458         3458   Department of Natural Resources
# 6491         6491      Department of Transportation
# 683           683   Department of Natural Resources
# 6886         6886    Department of Military Affairs
# 2463         2463   Department of Natural Resources
# 5613         5613         Department of Corrections
# 2370         2370            University of Illinois
# 2944         2944   Department of Natural Resources
# 7984         7984  Northeastern Illinois University
# 6417         6417      Department of Transportation
# 4595         4595         Department of Corrections
# 5584         5584         Department of Corrections
# 3340         3340   Department of Natural Resources
# 7853         7853      Southern Illinois University
# 8738         8738      Department of Transportation
# 397           397   Department of Natural Resources
# 3780         3780   Department of Natural Resources
# 6318         6318      Department of Transportation
# 3474         3474   Department of Natural Resources
# 2862         2862   Department of Natural Resources
# 3141         3141      Historic Preservation Agency
# 4085         4085         Department of Corrections
# 7352         7352            University of Illinois
# 4927         4927         Department of Corrections
# 6773         6773        Department of State Police
# 7717         7717      Southern Illinois University
# 7692         7692      Southern Illinois University
#
#                                           Location Name  \
# 4269              Kiley Developmental Center - Waukegan
# 5535  Taylorville Correctional Center - Christian Co...
# 1557            Illinois Beach State Park - Lake County
# 3458                      Randolph Fish & Wildlife Area
# 6491              Carbondale - District #9 Headquarters
# 683             Lincoln Trail State Park - Clark County
# 6886                      Kewanee Armory - Henry County
# 2463           Franklin Creek Natural Area - Lee County
# 5613  Illinois River (Canton)  Correctional Center -...
# 2370            University of Illinois Urbana-Champaign
# 2944                 Illini State Park - LaSalle County
# 7984         Northeastern Illinois University - Chicago
# 6417  Mt. Vernon Maintenance Storage Facility - Jeff...
# 4595           Joliet Correctional Center - Will County
# 5584  Western Illinois Correctional Center - Mount S...
# 3340            Beaver Dam State Park - Macoupin County
# 7853          Southern Illinois University - Carbondale
# 8738  Morton Maintenance Storage Facility - Tazewell...
# 397     Wayne Fitzgerrell State Park - Jefferson County
# 3780          Pere Marquette State Park - Jersey County
# 6318  Jacksonville Maintenance Storage Facility - Mo...
# 3474                Washington County Conservation Area
# 2862     Giant City State Park & Lodge - Jackson County
# 3141  Lincoln's New Salem Historic Site - Menard County
# 4085             Dixon Correctional Center - Lee County
# 7352            University of Illinois Urbana-Champaign
# 4927      Sheridan Correctional Center - LaSalle County
# 6773              Metamora District 8 - Woodford County
# 7717          Southern Illinois University - Carbondale
# 7692          Southern Illinois University - Carbondale
#
#                           Address            City Zip code      County  \
# 4269               Dugdale Circle        Waukegan    60085        Lake
# 5535    Rt 29 South P.o. Box 1000     Taylorville    62568   Christian
# 1557  Il Beach State Park, Ranger            Zion    60099        Lake
# 3458             R. R. 1, Box 345         Chester    62233    Randolph
# 6491        2801 West Murphysboro      Carbondale    62901     Jackson
# 683                 Rr #1 Box 117        Marshall    62441       Clark
# 6886        111 North East Street         Kewanee    61443       Henry
# 2463              1872 Twist Road  Franklin Grove    61031         Lee
# 5613                 Route 9 West          Canton    61520      Fulton
# 2370   1910 South Giriffith Drive       Champaign    61820   Champaign
# 2944                Rural Route 1      Marseilles    61341     LaSalle
# 7984         5500 North St. Louis         Chicago    60625        Cook
# 6417             1 Fountain Place       Mt Vernon    62864   Jefferson
# 4595          1125 Collins Street          Joliet    60432        Will
# 5584               R.r. 4 Box 196     Mt Sterling    62353       Brown
# 3340        14548 Beaver Dam Lane       Plainview    62676    Macoupin
# 7853    1206 Touch Of Nature Road         Makanda    62958     Jackson
# 8738        1971 N. Morton Avenue          Morton    61550    Tazewell
# 397              R. R. #1, Box 73     Whittington    62897   Jefferson
# 3780                 P.o. Box 158         Grafton    62037      Jersey
# 6318       500 East Walnut Street    Jacksonville    62650      Morgan
# 3474                      R. R. 3       Nashville    62263  Washington
# 2862                  P.o. Box 70         Makanda    62958     Jackson
# 3141             Rr #1, Box 244-a      Petersburg    62675      Menard
# 4085           2600 North Brinton           Dixon    61021         Lee
# 7352                 Windsor Road          Urbana    61801   Champaign
# 4927          4017 East 2603 Road        Sheridan    60551     LaSalle
# 6773      Route 116 & Lordes Road        Metamora    61548    Woodford
# 7717          2185 Wildlife Drive      Carbondale    62901     Jackson
# 7692  707 South Washington Square      Carbondale    62901     Jackson
#
#       Congress Dist Congressional Full Name  Rep Dist  ... Year Acquired  \
# 4269             10             Robert Dold        60  ...          1975
# 5535             13         Rodney L. Davis        95  ...          1990
# 1557             10             Robert Dold        61  ...          1921
# 3458             12               Mike Bost       114  ...          2000
# 6491             12               Mike Bost       115  ...          1981
# 683              15            John Shimkus       110  ...          2002
# 6886             17            Cheri Bustos        74  ...          1950
# 2463             16          Adam Kinzinger        90  ...          1984
# 5613             17            Cheri Bustos        91  ...          1989
# 2370             13         Rodney L. Davis       103  ...          1975
# 2944             16          Adam Kinzinger        76  ...          1990
# 7984              5            Mike Quigley        15  ...          1965
# 6417             12               Mike Bost       115  ...          1992
# 4595             11             Bill Foster        86  ...          1985
# 5584             18         Darin M. LaHood        93  ...          1989
# 3340             13         Rodney L. Davis        95  ...          1992
# 7853             12               Mike Bost       115  ...          1953
# 8738             18         Darin M. LaHood        88  ...          2011
# 397              12               Mike Bost       117  ...          2001
# 3780             13         Rodney L. Davis       100  ...          1950
# 6318             18         Darin M. LaHood       100  ...          1973
# 3474             15            John Shimkus       115  ...          1989
# 2862             12               Mike Bost       118  ...          1970
# 3141             18         Darin M. LaHood        87  ...          1935
# 4085             16          Adam Kinzinger        90  ...          1983
# 7352             13         Rodney L. Davis       103  ...          1981
# 4927             16          Adam Kinzinger        75  ...          1984
# 6773             18         Darin M. LaHood        73  ...          1964
# 7717             12               Mike Bost       115  ...          1965
# 7692             12               Mike Bost       115  ...          1967
#
#       Year Constructed Square Footage Total Floors  Floors Above Grade  \
# 4269              1974           2909            2                   2
# 5535              1990             60            1                   1
# 1557              1921            740            1                   1
# 3458              2000            104            1                   1
# 6491              1981          12160            1                   1
# 683               2002            104            1                   1
# 6886              1950          12272            1                   1
# 2463              1984            520            1                   1
# 5613              1987            144            1                   1
# 2370              1975           3540            1                   1
# 2944              1990            506            1                   1
# 7984              1961          36374            1                   1
# 6417              1992           4070            1                   1
# 4595              1985           1052            2                   2
# 5584              1989            160            1                   1
# 3340              1992            832            1                   1
# 7853              1953            232            1                   1
# 8738              2011            388            1                   0
# 397               2001            144            1                   1
# 3780              1950             30            1                   1
# 6318              1973           2922            1                   1
# 3474              1989             20            1                   1
# 2862              1970             24            1                   1
# 3141              1935            800            3                   2
# 4085              1983             98            1                   1
# 7352              1974           1880            1                   1
# 4927              1984            162            2                   2
# 6773              1964           6008            1                   1
# 7717              1965            958            1                   1
# 7692              1960           8349            3                   3
#
#       Floors Below Grade   Usage Description  Usage Description 2  \
# 4269                   0         Health Care          Health Care
# 5535                   0          Industrial           Industrial
# 1557                   0            Business             Business
# 3458                   0             Unusual              Unusual
# 6491                   0             Storage              Storage
# 683                    0             Unusual              Unusual
# 6886                   0             Storage           Industrial
# 2463                   0            Assembly             Assembly
# 5613                   0  Detention & Correc   Detention & Correc
# 2370                   0             Storage              Storage
# 2944                   0            Business             Business
# 7984                   0            Assembly             Assembly
# 6417                   0             Storage              Storage
# 4595                   0             Unusual              Unusual
# 5584                   0          Industrial           Industrial
# 3340                   0             Unusual              Unusual
# 7853                   0         Residential          Residential
# 8738                   1             Storage              Storage
# 397                    0             Unusual              Unusual
# 3780                   0             Unusual              Unusual
# 6318                   0             Storage              Storage
# 3474                   0             Unusual              Unusual
# 2862                   0             Unusual              Unusual
# 3141                   1            Assembly             Assembly
# 4085                   0  Detention & Correc   Detention & Correc
# 7352                   0             Unusual              Unusual
# 4927                   0  Detention & Correc   Detention & Correc
# 6773                   0            Business             Business
# 7717                   0             Unusual              Unusual
# 7692                   0         Residential             Business
#
#       Usage Description 3  Age at Acqusition
# 4269         Not provided                  1
# 5535         Not provided                  0
# 1557         Not provided                  0
# 3458         Not provided                  0
# 6491         Not provided                  0
# 683          Not provided                  0
# 6886              Storage                  0
# 2463         Not provided                  0
# 5613         Not provided                  2
# 2370         Not provided                  0
# 2944         Not provided                  0
# 7984             Business                  4
# 6417         Not provided                  0
# 4595         Not provided                  0
# 5584         Not provided                  0
# 3340         Not provided                  0
# 7853         Not provided                  0
# 8738         Not provided                  0
# 397          Not provided                  0
# 3780         Not provided                  0
# 6318         Not provided                  0
# 3474         Not provided                  0
# 2862         Not provided                  0
# 3141         Not provided                  0
# 4085         Not provided                  0
# 7352         Not provided                  7
# 4927         Not provided                  0
# 6773         Not provided                  0
# 7717         Not provided                  0
# 7692         Not provided                  7
#
# [30 rows x 24 columns]

# %% [markdown]
# # Histogram

# %%
# A hist draw from 'Age at Acquisition' column

fig, ax = plt.subplots() # make an empty figure

ax.hist(df_filtered['Age at Acqusition'], bins=5) # .hist() draws a histogram 
# .hist(df_filtered['Age at Acqusition']) draws a histogram using the 'Age at Acqusition' column
# bins=5 means 5 bins with equal width

plt.show()

# %%
# log scale

fig, ax = plt.subplots()

ax.hist(df_filtered['Age at Acqusition'], bins=10, log=True) # .hist() draw a histogram 
# .hist(df_filtered['Age at Acqusition']) draw a histogram using the 'Age at Acqusition' column
# bins=10 means 10 bins with equal width
# log=True makes the y as log scale. 

plt.show()

# %%
# non-uniform bins

fig, ax = plt.subplots()

ax.hist(df_filtered['Age at Acqusition'], bins=[0, 100, 200, 233], log=True)
# .hist() draw a histogram 
# .hist(df_filtered['Age at Acqusition']) draw a histogram using the 'Age at Acqusition' column

# bins=[0, 100, 200, 233] makes 3 bins:
# first bin incudes data values from 0 to less than 100
# second bin incudes data values from 100 to less than 200
# first bin incudes data values from 200 to 233 (233 is included.)

# log=True makes the y as log scale. 

plt.show()

# %% [markdown]
# # Bar chart

# %%
# A bar chart with groups using 'Bldg Status' column
# Group by categories, count 

print(df['Bldg Status'].unique()) # print unique values in Bldg Status colum

# Count how many bulidings belongs to each building status
df2draw = df.groupby(['Bldg Status'])[['Building ID']].count()
# .groupby() groups rows by unique values in the colum 
# .groupby(['Bldg Status']) group rows by the unique values in the Bldg Status colum
# [['Building ID']] selects the 'Building ID' column for counting the rows 
# .count() counts the non-null rows in the Building ID column

# In brief, this line of code first groups the rows by the unique values in Bldg Status colum
# then counts the number of non-null rows in the Building ID column belongs to each group
# We count the Building ID column beacuse each Building ID represents a building.


df2draw # show the result

# Explanation of the result: 
# 226 buildings have building status as Abandon
# 113 buildings have building status as In Progress
# 8523 buildings have building status as In Use
# Out:
# ['In Use' 'Abandon' 'In Progress']
#              Building ID
# Bldg Status
# Abandon              226
# In Progress          113
# In Use              8523

# %%
# Make a bar chart
fig, ax = plt.subplots() # Make an empty plot

ax.bar(df2draw.index, df2draw['Building ID'])
# .bar() draws a bar chart
# .bar(df2draw.index, df2draw['Building ID']) draw a bar chart in which
# Bldg Status (df2draw.index) as x
# Number of buldings (df2draw['Building ID']) as y

ax.set_xlabel('Buliding status') # Set the x label
ax.set_ylabel('Number of buildings') # Set the y label

plt.show()

# %%
fig, ax = plt.subplots()

ax.bar(df2draw.index, df2draw['Building ID'], log=True) # Same as above, but make y as log scale

ax.set_xlabel('Buliding status') # Set the x label
ax.set_ylabel('Number of buildings') # Set the y label

plt.show()

# %%
# Group by categories, sum 

df2draw = df_filtered.groupby(df_filtered['Bldg Status'])[['Square Footage']].sum()
# .groupby() groups rows by unique values in the colum 
# .groupby(['Bldg Status']) group rows by the unique values in the Bldg Status colum
# [['Square Footage']] selects the 'Square Footage' column 
# .sum() returns the sum of the values in the Square Footage column

# In brief, this line of code first groups the rows by the unique values in Bldg Status colum
# then calculate the sum of the values in the Square Footage column belongs to each group

df2draw # show the result
# Out:
#              Square Footage
# Bldg Status
# Abandon             1549029
# In Progress         1920188
# In Use             94406438

# %%
fig, ax = plt.subplots()

ax.bar(df2draw.index, df2draw['Square Footage'])
# .bar(df2draw.index, df2draw['Square Footage']) draw a bar chart in which
# Bldg Status (df2draw.index) as x
# Sum of Square Footage (df2draw['Square Footage']) as y

ax.set_xlabel('Building Status') # Set x label
ax.set_ylabel('Total Square Footage') # Set y label

plt.show()

# %%
# Group by categories, mean 

df2draw = df_filtered.groupby(df_filtered['Bldg Status'])[['Square Footage']].mean()
# .groupby(['Bldg Status']) group rows by the unique values in the Bldg Status colum
# [['Square Footage']] selects the 'Square Footage' column 
# .mean() returns the mean of the values in the Square Footage column

# In brief, this line of code first groups the rows by the unique values in Bldg Status colum
# then calculate the mean of the values in the Square Footage column belongs to each group

df2draw # shows the result
# Out:
#              Square Footage
# Bldg Status
# Abandon         7630.684729
# In Progress    22327.767442
# In Use         11649.363031

# %%
fig, ax = plt.subplots()

ax.bar(df2draw.index, df2draw['Square Footage'])
# .bar(df2draw.index, df2draw['Square Footage']) draw a bar chart in which
# Bldg Status (df2draw.index) as x
# Mean of Square Footage (df2draw['Square Footage']) as y

ax.set_ylabel('Mean of Square Footage') # Set x label
ax.set_xlabel('Building Status') # Set y label

plt.show()

# %% [markdown]
# # Scatter plot
# [matplotlib.markers](https://matplotlib.org/stable/api/markers_api.html)
# [linestyle](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html)

# %%
# Draw a scatter plot by using plt.plot 
x = [1, 2, 3, 4]
y = [4, 3, 4, 2]

fig, ax = plt.subplots() # create an empty figure

ax.plot(x, y, marker='o', linestyle='') 
# marker='o' defines the markers (i.e., x and y coordinates) as circles
# linestyle='' sets the lines connecting the markers invisible. 

plt.show()

# %%
# Draw a scatter plot by using .scatter()

fig, ax = plt.subplots() # create an empty figure

ax.scatter(x, y) # .scatter() draw a scatter plot using the x and y values

plt.show()

# %%
# Without cleaning the data...

x = df['Year Constructed']
y = df['Year Acquired']

fig, ax = plt.subplots()

ax.scatter(x, y)

plt.show()

# %%
# Cleaned data

x = df_filtered['Year Constructed']
y = df_filtered['Year Acquired']

fig, ax = plt.subplots()

ax.scatter(x, y)

ax.set_xlabel('Year Constructed')
ax.set_ylabel('Year Acquired')

plt.show()

# %% [markdown]
# # Line plot

# %%
# Number of buldings along year constructed

df2draw = df_filtered.groupby(df_filtered['Year Constructed'])[['Building ID']].count()
# .groupby(['Year Constructed']) group rows by the unique values in the Year Constructed colum
# [['Building ID']] selects the 'Building ID' column 
# .count() counts the number of rows in the Building ID column belonging to each group

# In brief, this line of code first groups the rows by the unique values in Year Constructed colum
# then count the rows in the Building ID column belongs to each group (i.e., how many buldings in each group)

df2draw # Shows the result
# Out:
#                   Building ID
# Year Constructed
# 1753                        6
# 1802                        2
# 1810                        3
# 1812                        1
# 1815                        1
# ...                       ...
# 2015                       20
# 2016                        9
# 2017                        1
# 2018                        4
# 2019                        2
#
# [178 rows x 1 columns]

# %%
fig, ax = plt.subplots()

ax.plot(df2draw.index, df2draw['Building ID'])
# .plot() draws the line plot
# X as years in Year Constructed (df2draw.index)
# Y as number of buildings (df2draw['Building ID'])

ax.set_xlabel('Year Constructed') # X label
ax.set_ylabel('Number of buildings') # Y label

plt.show()

# %% [markdown]
# # Color, marker, and size

# %%
# We can iterate over the groups

# .group() returns a group object
groups = df_filtered.groupby(df_filtered['Bldg Status'])
type(groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
# We can iterate over the groups

for name, group in groups:
    print(name, type(group))
    # name are the unique values in the colum used for groupby(). In this case, names are the uinique values in Bldg Status column
    # group return the rows belonging to a group
# Out:
# Abandon <class 'pandas.core.frame.DataFrame'>
# In Progress <class 'pandas.core.frame.DataFrame'>
# In Use <class 'pandas.core.frame.DataFrame'>

# %%
# Color by group

groups = df_filtered.groupby(df_filtered['Bldg Status'])

fig, ax = plt.subplots(figsize=(10, 10))

colors = {'Abandon': 'red', 'In Progress': 'blue', 'In Use': 'black'} # This is a dictionay for looking up colors


for name, group in groups: # Iterate over groups
    # plot dots on scatter plot, each time plots the dots belongs to a group
    ax.scatter(group['Year Constructed'], group['Year Acquired'], color=colors[name])
    
    # group['Year Constructed'] are X values in the scatter plot
    # group['Year Acquired'] are Y values in the scatter plot
    # color= defines the color of the dots in a scatter plot
    # color=colors[name] assigns colors to dots by looking up colors given in the "colors" dictionary
    
plt.show()

# %%
# Marks by group
groups = df_filtered.groupby(df_filtered['Bldg Status'])

fig, ax = plt.subplots(figsize=(10, 10))

colors = {'Abandon': 'red', 'In Progress': 'blue', 'In Use': 'black'} # This is a dictionay for looking up colors
markers = {'Abandon': 'o', 'In Use': '^', 'In Progress': 'D'} # This is a dictionay for looking up markers

for name, group in groups:
    print(name, type(group), colors[name])
    ax.scatter(group['Year Constructed'], group['Year Acquired'], 
               color=colors[name], marker=markers[name])
    
    # group['Year Constructed'] are X values in the scatter plot
    # group['Year Acquired'] are Y values in the scatter plot
    # marker= assigns the marker to dots in a scatter plot
    # marker=markers[name] assigns markers to dots by looking up markers given in the "markers" dictionary
    
plt.show()
# Out:
# Abandon <class 'pandas.core.frame.DataFrame'> red
# In Progress <class 'pandas.core.frame.DataFrame'> blue
# In Use <class 'pandas.core.frame.DataFrame'> black

# %%
# Size by group

groups = df_filtered.groupby(df_filtered['Bldg Status'])

fig, ax = plt.subplots(figsize=(10, 10))

colors = {'Abandon': 'red', 'In Progress': 'blue', 'In Use': 'black'} # This is a dictionay for looking up colors
sizes = {'Abandon': 100, 'In Progress': 50, 'In Use':5} #  This is a dictionay for looking up sizes

for name, group in groups:
    print(name, type(group))
    ax.scatter(group['Year Constructed'], group['Year Acquired'], color=colors[name], s=sizes[name])
    
    # group['Year Constructed'] are X values in the scatter plot
    # group['Year Acquired'] are Y values in the scatter plot
    # s= assigns dot size
    # s=sizes[name] assigns dot size by looking up the size given in the "sizes" dictionary
    
plt.show()
# Out:
# Abandon <class 'pandas.core.frame.DataFrame'>
# In Progress <class 'pandas.core.frame.DataFrame'>
# In Use <class 'pandas.core.frame.DataFrame'>
